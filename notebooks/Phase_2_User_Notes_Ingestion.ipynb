# %% [markdown]
# # Phase 2 — User Notes Ingestion
# ## Fase 2 — Ingreso de Notas del Usuario
#
# **Marginalia — Your literary assistant.**
# *Marginalia — Tu asistente literario.*
#
# ---
#
# This notebook builds the module that captures personal reading reflections.
#
# *Este notebook construye el módulo que captura las reflexiones personales de lectura.
#
#
# **What this phase produces / Qué produce esta fase:**
# - `notes_manager.py` — reusable module, lives in Google Drive
# - `user_notes.csv` — persistent notes store, same folder as `books_clean.csv`
# - `df_notas` — DataFrame ready for Phase 3

# %% [markdown]
# ## Step 1 — Mount Google Drive / Montar Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive')
print(" Google Drive mounted.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  Google Drive mounted.

# %% [markdown]
# ## Step 2 — Load the NotesManager Module / Cargar el módulo NotesManager
#
# > **Before running / Antes de ejecutar:** Make sure `notes_manager.py` is uploaded to the project folder in Drive.

# %%
import shutil
import os

DRIVE_PATH = "/content/drive/MyDrive/Colab Notebooks/PF_Ironhack/"

source      = os.path.join(DRIVE_PATH, "notes_manager.py")
destination = "/content/notes_manager.py"

if os.path.exists(source):
    shutil.copy(source, destination)
    print(f"notes_manager.py loaded from Drive.")
else:
    raise FileNotFoundError(
        f"notes_manager.py not found at: {source}\n"
        "Upload the file to your Drive project folder before running this cell."
    )
# Out:
# notes_manager.py loaded from Drive.

# %% [markdown]
# ## Step 3 — Initialize NotesManager / Inicializar NotesManager
#
# **EN:** Creates the NotesManager instance pointing to the project folder.
# On first run it creates `user_notes.csv`. On subsequent runs it loads existing notes.
#
# **ES:** Crea la instancia de NotesManager apuntando a la carpeta del proyecto.
# En la primera ejecución crea `user_notes.csv`. En ejecuciones posteriores carga las notas existentes.

# %%
from notes_manager import NotesManager

nm = NotesManager(drive_path=DRIVE_PATH)

# %% [markdown]
# ## Step 4 — Add Reading Notes / Agregar Notas de Lectura
#
# **EN:** Each `nm.add_note()` call adds one book. The note is saved to Drive immediately.
# Run this cell to populate or extend the notes collection.
#
# **ES:** Cada llamada a `nm.add_note()` agrega un libro. La nota se guarda en Drive inmediatamente.
# Ejecuta esta celda para poblar o ampliar la colección de notas.

# %%
# --- Book 01 ---
nm.add_note(
    title='The Name of the Wind',
    author='Patrick Rothfuss',
    note_text='A deeply poetic and immersive narrative. Kvothe is a complex and contradictory character, I loved and hated him at the same time. The Alar magic system is brilliantly crafted.',
    rating=5,
    tags='fantasy, magic, epic-narrator',
    date_read='2023-11-20'
)

# --- Book 02 ---
nm.add_note(
    title='Dune',
    author='Frank Herbert',
    note_text='Epic and philosophical. The interplanetary politics and themes of ecology and religion kept me thinking for weeks. Slow at first but then impossible to put down.',
    rating=5,
    tags='scifi, politics, epic, ecology',
    date_read='2023-09-05'
)

# --- Book 03 ---
nm.add_note(
    title='The Little Prince',
    author='Antoine de Saint-Exupéry',
    note_text='Seems simple but every reread reveals something new. The protagonist\'s loneliness and the theme of seeing with the heart move me deeply.',
    rating=4,
    tags=' philosophical, melancholic',
    date_read='2024-01-15'
)

# --- Book 04 ---
nm.add_note(
    title='1984',
    author='George Orwell',
    note_text='Disturbing and necessary. Total surveillance and language as a weapon of control felt more relevant than ever. Julia\'s relationship with Winston adds humanity to the dystopia.',
    rating=5,
    tags='dystopia, political, dark, classic',
    date_read='2023-06-10'
)

# --- Book 05 ---
nm.add_note(
    title='Sapiens',
    author='Yuval Noah Harari',
    note_text='Changed my perspective on human history. The idea that collective fictions bind us together is fascinating. Sometimes oversimplifies but the overall impact is undeniable.',
    rating=4,
    tags='non-fiction, history, society',
    date_read='2024-02-28'
)

# --- Book 06 ---
nm.add_note(
    title='The Catcher in the Rye',
    author='J.D. Salinger',
    note_text='Intimate and deeply vulnerable. Holden Caulfield\'s voice felt honest, chaotic, and full of contained pain. His cynicism toward the adult world hides a desperate need for connection and purity.',
    rating=4,
    tags='coming-of-age, existential, melancholic',
    date_read='2024-03-01'
)

# --- Book 07 ---
nm.add_note(
    title='Ubik',
    author='Philip K. Dick',
    note_text='Disorienting and philosophically unsettling. Reality constantly collapses and I am never sure what is true. I was fascinated by the sense of ontological paranoia and the fragility of time.',
    rating=5,
    tags='scifi, fractured-reality, paranoia, philosophical',
    date_read='2024-03-01'
)

# --- Book 08 ---
nm.add_note(
    title='A Supposedly Fun Thing I\'ll Never Do Again',
    author='David Foster Wallace',
    note_text='Ironic, brilliant, and obsessively detailed. Wallace turns the trivial into an existential exploration of boredom, consumerism, and self-consciousness. It made me laugh and feel uncomfortable at the same time.',
    rating=4,
    tags='essay, irony, introspective',
    date_read='2024-03-01'
)

# --- Book 09 ---
nm.add_note(
    title='Man\'s Search for Meaning',
    author='Viktor E. Frankl',
    note_text='Sober and deeply human. The experience in the concentration camps is devastating, but the reflection on meaning as a driving force for survival is luminous. It left me thinking about inner responsibility.',
    rating=5,
    tags='psychology, existentialism, resilience',
    date_read='2024-03-01'
)

# --- Book 10 ---
nm.add_note(
    title='Ask the Dust',
    author='John Fante',
    note_text='Raw and vulnerable. Arturo Bandini is arrogant and fragile at the same time, trapped between literary ambition and self-loathing. The atmosphere of Los Angeles adds a dusty, desperate sense of loneliness.',
    rating=4,
    tags='existentialism, writer-protagonist, loneliness, realism',
    date_read='2024-03-01'
)

# --- Book 11 ---
nm.add_note(
    title='Crime and Punishment',
    author='Fyodor Dostoevsky',
    note_text='What strikes me most is how Dostoevsky approaches moral conflict and guilt by placing the protagonist in a situation nobody would wish for, yet one that anyone could face through the accidental circumstances of life. The construction of the character is so real, with all the facets and dualities of human nature, that it is impossible not to empathize with him in his pain and suffering.',
    rating=5,
    tags='classic, psychological, moral, guilt, russian-literature',
    date_read='2023-06-10'
)

# --- Book 12 ---
nm.add_note(
    title='Factotum',
    author='Charles Bukowski',
    note_text='What I love most about this autobiographical novel is how Bukowski, or rather Chinaski, seems to have no control over his life — he jumps from job to job, drinks too much, chases women — yet none of this makes him question his worth as a person or as a writer. Rejection from publishers frustrates him, but he knows his work is good. This unbreakable self-respect and his constant dedication to his passion, without letting the mundane pressures of social life distract him from his purpose or his identity, is deeply admirable.',
    rating=5,
    tags='autobiographical, raw, self-respect, identity, counterculture',
    date_read='2023-08-22'
)

# --- Book 13 ---
nm.add_note(
    title='Pride and Prejudice',
    author='Jane Austen',
    note_text='A beautiful romantic novel where dialogue, respect, and patience build a love story that transcends its era and feels almost pure. Austen constructs her characters with wit and precision, and the slow unfolding of understanding between Elizabeth and Darcy feels earned and genuinely moving.',
    rating=4,
    tags='romance, classic, wit, society, character-driven',
    date_read='2024-02-14'
)

# --- Book 14 ---
nm.add_note(
    title='Wilt',
    author='Tom Sharpe',
    note_text='Intelligent, funny, satirical, honest, and quietly sad. This novel depicts the kind of character I feel most connected to: ordinary people with so-called boring jobs who live largely inside their own thoughts and refuse to let society\'s absurd trends or prejudices bend their character. Wilt remains stubbornly anchored to truth even when that truth works against him. He could disguise his feelings and motivations, but he doesn\'t — and one can only feel admiration for someone who stays faithful to honesty while the world seems to move toward manipulation and frivolous excess.',
    rating=5,
    tags='satire, british-humor, identity, ordinary-life, social-critique',
    date_read='2023-12-05'
)

# --- Book 15 ---
nm.add_note(
    title='The Royal Game',
    author='Stefan Zweig',
    note_text='What fascinated me most is the contrast between the two main characters, who come from vastly different backgrounds yet share a common thread of trauma, and how both have become chess masters through it. The narrator is an exceptional observer of individuals, and his account of events unfolding during a sea voyage feels as tense and dramatic as a duel to the death.',
    rating=4,
    tags='chess, trauma, psychological, zweig',
    date_read='2024-03-18'
)

# --- Book 16 ---
nm.add_note(
    title='Perfume: The Story of a Murderer',
    author='Patrick Süskind',
    note_text='One of my favorite books for how it makes you empathize with the protagonist. A character born and raised in unjust, painful, and traumatic circumstances who becomes a murderer — yet Süskind transforms him into an artist, a person of extraordinary sensibility, a pursuer of beauty. The story is full of dichotomies that feel like a metaphor for the deepest human nature: a monstrous killer with superhuman gifts who is also, in his own warped way, a lover of beauty.',
    rating=5,
    tags='dark, psychological, sensory, obsession, literary-fiction',
    date_read='2023-04-30'
)

# --- Book 17 ---
nm.add_note(
    title='I Am Alive and You Are Dead',
    author='Emmanuel Carrère',
    note_text='Philip K. Dick is one of my favorite sci-fi writers, and the way Carrère narrates his life as if one were inside Dick\'s own mind made me appreciate him even more. The fluidity with which thoughts and situations are described leaves no gaps — even when years are skipped and then returned to, you never feel you left his side. Carrère describes Dick in the way I believe true artists must be understood: as channelers of a collective consciousness, translators of something that already exists in another plane of reality, one they can access even if they sometimes struggle to close that door — and which can transform them into what those without that sensitivity might call madness.',
    rating=5,
    tags='biography, philip-k-dick, scifi, consciousness, creativity',
    date_read='2024-05-12'
)

# --- Book 18 ---
nm.add_note(
    title='The Man in the High Castle',
    author='Philip K. Dick',
    note_text='Dick constructs an alternate history with the quiet unease of someone who suspects our own reality might be equally constructed. What stays with me is not the plot but the philosophical vertigo it produces — the sense that authenticity is fragile and consensus reality is just another story we agree to tell each other.',
    rating=5,
    tags='scifi, alternate-history, reality, philosophical',
    date_read='2022-11-08'
)

# --- Book 19 ---
nm.add_note(
    title='Confessions of a Mask',
    author='Yukio Mishima',
    note_text='An unsettling and precise excavation of inner life. Mishima writes about the distance between one\'s true self and the face presented to the world with a kind of clinical honesty that is almost unbearable. The tension between desire, shame, and social performance feels universal even as it is deeply personal.',
    rating=4,
    tags='identity, mask, psychological, sexuality',
    date_read='2023-02-20'
)

# --- Book 20 ---
nm.add_note(
    title='Let the Right One In',
    author='John Ajvide Lindqvist',
    note_text='Not a horror novel so much as a portrait of loneliness. The relationship between Oskar and Eli is one of the most tender and disturbing things I have read — two outcasts finding in each other the only understanding either has ever known. The cold Swedish setting becomes almost a character itself, amplifying the isolation.',
    rating=4,
    tags='horror, loneliness, friendship, dark',
    date_read='2023-07-15'
)

# --- Book 21 ---
nm.add_note(
    title='The Tunnel',
    author='Ernesto Sábato',
    note_text='A brutal and claustrophobic descent into obsessive thought. Castel is a man destroyed by his own intelligence and hypersensitivity — he sees connections where none exist and builds an entire emotional architecture on a single glance. Sábato captures that particular torment of the person who thinks too much and feels too deeply for their own good.',
    rating=5,
    tags='obsession, psychological, existential, dark',
    date_read='2022-09-03'
)

# --- Book 22 ---
nm.add_note(
    title='On Heroes and Tombs',
    author='Ernesto Sábato',
    note_text='A vast and haunting novel that moves between Buenos Aires and the interior of consciousness. The section narrated from within madness is one of the most daring pieces of writing I have encountered — Sábato does not explain or contain the experience but places you inside it. A book that demands something of the reader and gives back more.',
    rating=5,
    tags='madness, epic, consciousness, dark',
    date_read='2022-10-28'
)

# --- Book 23 ---
nm.add_note(
    title='Frankenstein',
    author='Mary Shelley',
    note_text='What Shelley understood that many adaptations miss is that the monster is not the horror — the horror is abandonment. The creature is articulate, sensitive, and desperately in need of connection. Frankenstein\'s refusal to take responsibility for what he created is the true tragedy, and it feels disturbingly modern.',
    rating=4,
    tags='gothic, responsibility, identity, creation',
    date_read='2024-01-08'
)

# --- Book 24 ---
nm.add_note(
    title='Brave New World',
    author='Aldous Huxley',
    note_text='More disturbing than Orwell because it does not rely on fear — it relies on pleasure and comfort as instruments of control. A world where people are conditioned to want exactly what they are given feels less like fiction and more like a warning that arrived too early to be heard properly.',
    rating=5,
    tags='dystopia, scifi, social-control, identity',
    date_read='2023-10-14'
)

# --- Book 25 ---
nm.add_note(
    title='Animal Farm',
    author='George Orwell',
    note_text='Orwell\'s genius is compression — the entire arc of revolutionary idealism collapsing into authoritarianism told through farm animals with a precision that never feels reductive. The final image is one of the most quietly devastating in literature. Short, but it lingers.',
    rating=4,
    tags='political, allegory, satire, classic',
    date_read='2023-05-22'
)

# --- Book 26 ---
nm.add_note(
    title='The Brotherhood of the Grape',
    author='John Fante',
    note_text='Fante writes about fathers and sons with the kind of honesty that is almost embarrassing — you recognize in Nick Molise every contradiction you have ever seen in people you love. There is tenderness in his portrait of a difficult man, but never sentimentality. The wine, the arguments, the silence between them feel entirely real.',
    rating=4,
    tags='family, italian-american, father-son, honest',
    date_read='2023-03-09'
)

# --- Book 27 ---
nm.add_note(
    title='One Hundred Years of Solitude',
    author='Gabriel García Márquez',
    note_text='Reading this feels like remembering something you never experienced. García Márquez makes the impossible feel like memory and the real feel like invention. The Buendía family\'s repetitions across generations are hypnotic — the same names, the same mistakes, the same longing — as if history were not moving forward but circling an impossibility it cannot resolve.',
    rating=5,
    tags='magical-realism, family, epic, masterpiece',
    date_read='2022-08-10'
)

# --- Book 28 ---
nm.add_note(
    title='The Stranger',
    author='Albert Camus',
    note_text='Meursault\'s detachment is not coldness but a kind of radical honesty that society cannot tolerate. Camus makes you question whether the trial is really about murder or about a man who refused to perform the emotions others expected of him. Unsettling and precise.',
    rating=5,
    tags='existentialism, absurdism, classic, philosophical',
    date_read='2022-04-15'
)

# --- Book 29 ---
nm.add_note(
    title='Notes from Underground',
    author='Fyodor Dostoevsky',
    note_text='The Underground Man is exhausting and brilliant in equal measure. His paradoxes feel like traps he sets for himself — he cannot accept love or kindness without immediately destroying it. Dostoevsky seems to be writing not a character but a diagnosis of a certain kind of intelligent, self-sabotaging consciousness.',
    rating=5,
    tags='psychological, existential, dostoevsky, dark',
    date_read='2023-01-20'
)

# --- Book 30 ---
nm.add_note(
    title='Steppenwolf',
    author='Hermann Hesse',
    note_text='A novel about the unbearable tension between the desire for solitude and the hunger for connection. Harry Haller despises the bourgeois world he is simultaneously dependent on, and Hesse turns this contradiction into something almost musical. The Magic Theater section remains one of the strangest and most memorable things I have read.',
    rating=4,
    tags='philosophical, identity, solitude, inner-conflict',
    date_read='2022-06-30'
)

# --- Book 31 ---
nm.add_note(
    title='The Master and Margarita',
    author='Mikhail Bulgakov',
    note_text='A carnival of a novel — Satan visits Soviet Moscow and chaos ensues, but underneath the satire is a meditation on artistic integrity and what it costs to tell the truth in a society built on lies. The Pontius Pilate chapters feel like they belong to a different and equally magnificent book.',
    rating=5,
    tags='satire, magical-realism, art, truth',
    date_read='2024-04-05'
)

# --- Book 32 ---
nm.add_note(
    title='Nausea',
    author='Jean-Paul Sartre',
    note_text='Roquentin\'s experience of existence as something viscous and overwhelming is one of the most original things in twentieth century fiction. Sartre manages to make ontology felt rather than argued. The chestnut root scene is extraordinary — a moment where philosophy becomes physical sensation.',
    rating=4,
    tags='existentialism, philosophical, consciousness, sartre',
    date_read='2023-09-28'
)

# --- Book 33 ---
nm.add_note(
    title='The Wind-Up Bird Chronicle',
    author='Haruki Murakami',
    note_text='Murakami builds a world where the boundary between interior life and external reality is genuinely porous. Toru Okada\'s descent into a dry well becomes a metaphor for the kind of self-excavation that most people spend their lives avoiding. Strange, melancholic, and strangely comforting.',
    rating=4,
    tags='magical-realism, identity, melancholy, murakami',
    date_read='2024-06-20'
)

# --- Book 34 ---
nm.add_note(
    title='The Remains of the Day',
    author='Kazuo Ishiguro',
    note_text='A novel about repression so complete that the protagonist cannot name what he has lost until it is entirely too late. Stevens narrates his own tragedy without understanding it, and Ishiguro trusts the reader to see what he cannot. The sadness accumulates so quietly that when it finally arrives it is overwhelming.',
    rating=5,
    tags='british-fiction, repression, regret, class, quiet-masterpiece',
    date_read='2024-07-14'
)

# --- Book 35 ---
nm.add_note(
    title='Siddhartha',
    author='Hermann Hesse',
    note_text='Less a novel than a philosophical journey rendered in precise, luminous prose. What resonates is Hesse\'s insistence that understanding cannot be transmitted — it can only be experienced. Siddhartha must leave every teacher, including the Buddha, to find what can only be found alone.',
    rating=4,
    tags='philosophical, spirituality, self-discovery, eastern-wisdom',
    date_read='2022-03-25'
)

# --- Book 36 ---
nm.add_note(
    title='Ham on Rye',
    author='Charles Bukowski',
    note_text='Bukowski\'s most autobiographical work follows Chinaski from childhood through young adulthood with a honesty about poverty, violence, and the slow formation of an outsider\'s identity that never lapses into self-pity. The rage is real but so is the humor, and the two together produce something that feels true in a way that polished prose rarely does.',
    rating=5,
    tags='autobiographical, poverty, identity, raw',
    date_read='2023-08-05'
)

# --- Book 37 ---
nm.add_note(
    title='Flowers for Algernon',
    author='Daniel Keyes',
    note_text='The epistolary structure — watching Charlie\'s writing change as his intelligence grows and then recedes — is one of the most effective formal choices in science fiction. What Keyes understands is that intelligence without emotional development is its own kind of isolation, and the novel becomes a meditation on what we actually mean by human.',
    rating=5,
    tags='scifi, intelligence, humanity, emotional, epistolary',
    date_read='2022-07-19'
)

# --- Book 38 ---
nm.add_note(
    title='Chronicle of a Death Foretold',
    author='Gabriel García Márquez',
    note_text='García Márquez tells you who dies and how in the first paragraph, and then spends the entire novel making you feel the horror of inevitability. Everyone knew. Everyone could have stopped it. No one did. The mechanics of collective complicity have never been examined with such elegant precision.',
    rating=5,
    tags='magical-realism, inevitability, tragedy',
    date_read='2022-08-30'
)

# --- Book 39 ---
nm.add_note(
    title='Woman at Point Zero',
    author='Nawal El Saadawi',
    note_text='Firdaus speaks from death row with an authority and clarity that is shattering. El Saadawi does not soften the violence of the systems her protagonist moves through — poverty, patriarchy, exploitation — but Firdaus herself is never reduced to victimhood. Her final refusal is one of the most powerful acts in literature.',
    rating=5,
    tags='feminism, identity, resistance, powerful',
    date_read='2024-08-03'
)

# --- Book 40 ---
nm.add_note(
    title='The Metamorphosis',
    author='Franz Kafka',
    note_text='Kafka does not explain or allegorize — Gregor simply wakes up as an insect, and the horror is that his family\'s reaction feels entirely plausible. The bureaucracy of family love, the way usefulness and affection are entangled, the exhaustion of the caregiver — all of it rendered in prose of extraordinary precision and strange calm.',
    rating=5,
    tags='kafka, existential, absurdism, family, transformation',
    date_read='2022-02-14'
)

# --- Book 41 ---
nm.add_note(
    title='The Raven',
    author='Edgar Allan Poe',
    note_text='A hypnotic and suffocating poem. The raven as a symbol of irreversible loss hit me harder than expected. Poe manages to make grief feel like a physical presence in the room. The repetition of "nevermore" is both maddening and perfect.',
    rating=5,
    tags='poetry, gothic, grief, symbolism',
    date_read='2023-03-15'
)

# --- Book 42 ---
nm.add_note(
    title='The Fall of the House of Usher',
    author='Edgar Allan Poe',
    note_text='The house as a mirror of Roderick\'s mind is a brilliant device. I kept feeling the walls closing in. Poe builds dread without ever explaining it, which is far more disturbing than any explicit horror. The ending felt inevitable from the first page.',
    rating=5,
    tags='gothic, psychological-horror, decay, atmosphere',
    date_read='2023-03-28'
)

# --- Book 43 ---
nm.add_note(
    title='Berenice',
    author='Edgar Allan Poe',
    note_text='Deeply unsettling in a way that lingers. The narrator\'s obsession with Berenice\'s teeth is grotesque, but Poe frames it as a disease of the mind, not mere madness. It raises uncomfortable questions about perception, desire and sanity. Not easy to read, but impossible to forget.',
    rating=4,
    tags='gothic, obsession, psychological, dark',
    date_read='2023-04-10'
)

# --- Book 44 ---
nm.add_note(
    title='The Martian Chronicles',
    author='Ray Bradbury',
    note_text='More melancholy than science fiction. Each story feels like a small elegy for something humanity lost or destroyed. The Martians are hauntingly beautiful and their erasure feels like a quiet atrocity. Bradbury writes about colonialism and nostalgia without ever being didactic.',
    rating=5,
    tags='science-fiction, melancholy, colonialism, short-stories',
    date_read='2023-06-02'
)

# --- Book 45 ---
nm.add_note(
    title='The Illustrated Man',
    author='Ray Bradbury',
    note_text='The framing device of living tattoos is genius. Some stories are pure dread, others are quietly devastating. "The Veldt" stayed with me for days. Bradbury uses technology as a lens to examine what we truly fear about ourselves, not machines, but our own emptiness.',
    rating=5,
    tags='science-fiction, short-stories, technology, existential',
    date_read='2023-07-14'
)

# --- Book 46 ---
nm.add_note(
    title='Zero K',
    author='Don DeLillo',
    note_text='Dense and hypnotic. DeLillo turns cryonics into a meditation on language, death and what it means to be a self. The prose is deliberately cold, almost clinical, which mirrors the subject perfectly. I had to reread entire paragraphs just to feel something. Difficult but rewarding.',
    rating=4,
    tags='literary-fiction, death, identity, language, postmodern',
    date_read='2024-01-20'
)

# --- Book 47 ---
nm.add_note(
    title='White Noise',
    author='Don DeLillo',
    note_text='Funny and terrifying at the same time. The fear of death hums underneath every mundane scene like white noise, exactly as the title promises. Jack Gladney is absurd and deeply human. DeLillo captures how modern life buries existential dread under consumerism and information overload.',
    rating=5,
    tags='literary-fiction, postmodern, death, consumerism, satire',
    date_read='2024-02-15'
)

# --- Book 48 ---
nm.add_note(
    title='Story of Your Life',
    author='Ted Chiang',
    note_text='One of the most quietly devastating things I have ever read. The non-linear structure is not a gimmick, it is the entire emotional argument of the story. Learning a new language changes how you experience time, and Chiang makes you feel that truth rather than just understand it. The ending broke me.',
    rating=5,
    tags='science-fiction, linguistics, time, grief, short-stories',
    date_read='2024-03-08'
)

# --- Book 49 ---
nm.add_note(
    title='The Alchemist',
    author='Paulo Coelho',
    note_text='A simple fable with an honest heart. I was skeptical of the universality of the Personal Legend concept, it feels too neat. But the journey across the desert has a genuine meditative quality. Best read without expecting philosophy and just letting the symbols wash over you.',
    rating=3,
    tags='fable, spirituality, journey, symbolism',
    date_read='2022-08-30'
)

# --- Book 50 ---
nm.add_note(
    title='Don Quixote',
    author='Miguel de Cervantes',
    note_text='Funnier and sadder than I expected. Quixote is not simply deluded, he is someone who chose a more meaningful world and paid the full price for it. Sancho Panza is the true philosophical heart of the book. The tension between idealism and reality never resolves, and that is precisely the point.',
    rating=5,
    tags='classic, idealism, satire, identity, meta-fiction',
    date_read='2022-12-01'
)

print(f"\n Done. Total notes in collection: {len(nm.notes_df)}")
# Out:
#  Done. Total notes in collection: 50

# %% [markdown]
# ## Step 5 — Verify & Inspect / Verificar e Inspeccionar
#
# **EN:** Confirm the notes saved correctly and inspect key statistics.
# **ES:** Confirmar que las notas se guardaron correctamente e inspeccionar estadísticas clave.

# %%
import pandas as pd

# Load directly from Drive to confirm persistence
df_check = pd.read_csv(os.path.join(DRIVE_PATH, "user_notes.csv"))

print(f"user_notes.csv verified.")
print(f"   Rows    : {len(df_check)}")
print(f"   Columns : {list(df_check.columns)}")
print()

# Statistical summary
nm.get_stats()

# Display full table
df_check
# Out:
# user_notes.csv verified.
#    Rows    : 50
#    Columns : ['note_id', 'title', 'author', 'note_text', 'rating', 'tags', 'date_read', 'date_added', 'processed']
#
#
# ...
# NOTES STATISTICS
# ...
# Total notes     : 50
# Average rating  : 4.6 / 5.0
# Avg note length : 301 characters
# Top 5 tags      :
#   identity: 11
#   philosophical: 7
#   psychological: 7
#   dark: 7
#   classic: 6
# ...
#      note_id                                       title  \
# 0   73fecee7                        The Name of the Wind
# 1   993c2b1b                                        Dune
# 2   751fa695                           The Little Prince
# 3   942a6e19                                        1984
# 4   22b3bd9d                                     Sapiens
# 5   beaa6c11                      The Catcher in the Rye
# 6   c6be1b9a                                        Ubik
# 7   82ec4983  A Supposedly Fun Thing I'll Never Do Again
# 8   9e8b05c4                    Man's Search for Meaning
# ...

# %% [markdown]
# ## Step 6 — [Optional] Delete a Note / [Opcional] Eliminar una Nota
#
# **EN:** Use this if you need to correct a note. Get the ID from `nm.show_notes()`.
# **ES:** Úsalo si necesitas corregir una nota. Obtén el ID con `nm.show_notes()`.

# %%
# Uncomment and replace the ID to delete a note
# nm.delete_note("REPLACE_WITH_NOTE_ID")

print("Delete cell is disabled. Uncomment the line above to use it.")
